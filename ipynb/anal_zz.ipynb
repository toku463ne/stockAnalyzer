# %%
import __init__

# %%
from env import *
import json
from analyzer.zz_analyzer import ZzAnalyzer

data = ""
with open("%s/%s" % (BASE_DIR, "anal_zz_conf.json"), "r") as f:
    data = json.load(f)
n_points = data["n_points"]
granularity = data["granularity"]
kmpkl_file = ""
a = ZzAnalyzer(granularity, n_points, kmpkl_file)
df_feed = a.getDeflectedKmGroups()
df_exec = a.getDeflectedKmGroups(km_mode=2, min_cnt_a_year=1)

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
df = pd.merge(df_feed, df_exec, on=["km_groupid"], how="inner")

df
# Out:
#                  total_x  total1_x  total2_x  score1_x  score2_x  total_y  \
# km_groupid
# 0011-0000000000        7       4.0       0.0  0.571429  0.000000        2
# 0011-0000000001       10      10.0       0.0  1.000000  0.000000        2
# 0011-0000000002        9       8.0       0.0  0.888889  0.000000        2
# 0011-0000000003        7       4.0       0.0  0.571429  0.000000        2
# 0022-0000000000       11       9.0       0.0  0.818182  0.000000        2
# 0022-0000000001       11       8.0       0.0  0.727273  0.000000        2
# 0022-0000000002        5       3.0       0.0  0.600000  0.000000        2
# 0022-0000000003       11      11.0       0.0  1.000000  0.000000        2
# 0100-0000000002        2       2.0       0.0  1.000000  0.000000        2
# 0100-0000000003        2       2.0       0.0  1.000000  0.000000        2
# 0111-0000000000       11       0.0       0.0  0.000000  0.000000        2
# ...

# %%
"0011-0000000005" in df.index
# Out:
# False
