# %% [markdown]
# ## Conclusion:
# The higher the score2 in anal_zzkmstats table, the higher win rate

# %%
import __init__

sql = """select p.km_id, count(p.km_id) as total,
greatest(sum(if(z.y6-z.y5>0,1,0)), sum(if(z.y6-z.y5<0,1,0))) as result
from clf_kmitems_predicted p
left join anal_zzpeaks_D_5_5 z on p.item_id = z.zzitemid
where p.clf_id = 1
group by km_id
having total >= 100
"""

sql = """select a.km_id, score, expected, total, result, result/total as rate
from (%s) as a
left join clf_kminfo info on a.km_id = info.km_id
order by score desc""" % (sql)

import pandas as pd
import numpy as np
from db.mydf import MyDf
mydf = MyDf()
df = mydf.read_sql(sql)
df
# Out:
#                    km_id     score  expected  total  result    rate
# 0   pek211212_0000000000  0.717557  0.372685    121    92.0  0.7603
# 1   pek211111_0000000000  0.584135  0.420625    135   103.0  0.7630
# 2   pek122222_0000000000  0.556522 -0.326488    158   113.0  0.7152
# 3   pek121001_0000000001  0.541176  0.614112    273   126.0  0.4615
# 4   pek210111_0000000001  0.451701  0.602595    148    82.0  0.5541
# 5   pek122121_0000000000  0.451613 -0.323748    116    96.0  0.8276
# 6   pek212102_0000000002  0.414400  0.677196    428   212.0  0.4953
# 7   pek121011_0000000006  0.402830 -0.339462    549   300.0  0.5464
# 8   pek212012_0000000000  0.389252  0.410908    401   210.0  0.5237
# 9   pek212022_0000000000  0.316564 -0.341154    380   200.0  0.5263
# 10  pek212111_0000000011  0.254049  0.289766   6525  3272.0  0.5015
# 11  pek121211_0000000014  0.246032 -0.412205   6147  3565.0  0.5800
# 12  pek120121_0000000002  0.207018 -0.354636    285   171.0  0.6000
# ...

# %%
df.corr()
# Out:
# /tmp/ipykernel_34036/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              score  expected     total    result      rate
# score     1.000000  0.267491 -0.447969 -0.444697  0.520161
# expected  0.267491  1.000000 -0.198976 -0.212786 -0.257494
# total    -0.447969 -0.198976  1.000000  0.998765  0.005395
# result   -0.444697 -0.212786  0.998765  1.000000  0.020060
# rate      0.520161 -0.257494  0.005395  0.020060  1.000000
